# %% [markdown]
# <a href="https://colab.research.google.com/github/reeda23/Open-CV101-OpenCV-Basics/blob/main/12_splitting_and_merging_channels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import packages
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
#read image
image = cv2.imread("/content/drive/MyDrive/OpenCV101 - Basics of OpenCV/opencvlogo.png")
#image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.title("Original Image")
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
(R, G, B) = cv2.split(image)

# %%
R.shape
# Out:
# (378, 428)

# %%
#R = cv2.cvtColor(R, cv2.COLOR_BGR2RGB)
plt.imshow(R)
plt.title("Red") #red component is fully filled up
# Out:
# Text(0.5, 1.0, 'Red')

# %%
#G = cv2.cvtColor(G, cv2.COLOR_BGR2RGB)
plt.imshow(G)
plt.title("Green")
# Out:
# Text(0.5, 1.0, 'Green')

# %%
#B = cv2.cvtColor(B, cv2.COLOR_BGR2RGB)
plt.imshow(B)
plt.title("Blue")
# Out:
# Text(0.5, 1.0, 'Blue')

# %%
merged = cv2.merge([R, G, B])
plt.imshow(merged)
