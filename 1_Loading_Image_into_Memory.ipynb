# %% [markdown]
# <a href="https://colab.research.google.com/github/reeda23/Computer-Vision-Journey/blob/main/1_Loading_Image_into_Memory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1st Method

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("/content/drive/MyDrive/persianCat.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.title("Cat")
# Out:
# Text(0.5, 1.0, 'Cat')

# %% [markdown]
# 2nd Method

# %%
from matplotlib import pyplot as plt
import argparse
import cv2

# %% [markdown]
# Funcion to Display images

# %%
def plt_imshow(title, image):

    #As Cv2 read image in BGR we have to convert it to RGB 
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.title(title)
    plt.grid(False)
    plt.show()

# %%
args = {
    "image" : "/content/drive/MyDrive/persianCat.jpg",
}

# %%
# load the image from disk via "cv2.imread" and then grab the spatial
# dimensions, including width, height, and number of channels
image = cv2.imread(args["image"])
h, w, c = image.shape[:3]
# display the image width, height, and number of channels to our
# terminal
print("width: {} pixels".format(image.shape[1]))
print("height: {}  pixels".format(image.shape[0]))
print("channels: {}".format(image.shape[2]))
# Out:
# width: 384 pixels
# height: 512  pixels
# channels: 3

# %%
plt_imshow("Persian Cat", image)
